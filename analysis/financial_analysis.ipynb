# %% [markdown]
# # Financial data about players and club (Everton FC)
#
# We are going to webscrape Transfermarkt for the player market values, how much the team spent on new signing and how much they recieved for players sold.
#
# Market value website: https://www.transfermarkt.co.uk/transfers/transferrekorde/statistik?saison_id=2017&land_id=0&ausrichtung=&spielerposition_id=&altersklasse=&leihe=&w_s=&plus=1
#
# Transfer info website: https://www.transfermarkt.com/premier-league/transfers/wettbewerb/GB1/saison_id/2017
#
# Everton squad market value: https://www.transfermarkt.com/everton-fc/kader/verein/29/plus/0/galerie/0?saison_id=2017

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Get out Player Name, Position, Left Club, Joined Club, Fee
player_names = []
player_positions = []
player_left_clubs = []
player_joined_clubs = []
player_fees = []
player_values = []

headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

base_url = "https://www.transfermarkt.co.uk/transfers/transferrekorde/statistik?saison_id=2017&land_id=0&ausrichtung=&spielerposition_id=&altersklasse=&leihe=&w_s=&plus=1&page="

# Loop through multiple pages
for page_number in range(1, 11):
    page = base_url + str(page_number)
    pageTree = requests.get(page, headers=headers)
    pageSoup = BeautifulSoup(pageTree.content, 'html.parser')
    player_rows = pageSoup.find_all("tr", {"class": ["odd", "even"]})

    for player_row in player_rows:
        player_name = player_row.select("a")[0].text
        player_position = player_row.select("td")[4].text
        player_left_club = player_row.select("td")[11].text
        player_joined_club = player_row.select("td")[15].text
        player_fee = player_row.select("td")[17].text
        player_value = player_row.select("td")[6].text

        player_names.append(player_name)
        player_positions.append(player_position)
        player_left_clubs.append(player_left_club)
        player_joined_clubs.append(player_joined_club)
        player_fees.append(player_fee)
        player_values.append(player_value)

df = pd.DataFrame({
    "Player Name": player_names,
    "Player Position": player_positions,
    "Left Club": player_left_clubs,
    "Current Club": player_joined_clubs,
    "Market Value (m€)": player_values,
    "Fee (m€)": player_fees
})

df
# Out:
#            Player Name     Player Position         Left Club   Current Club  \
# 0               Neymar         Left Winger      \nBarcelona     \nParis SG
# 1    Philippe Coutinho  Attacking Midfield      \nLiverpool    \nBarcelona
# 2      Ousmane Dembélé        Right Winger  \nBor. Dortmund    \nBarcelona
# 3        Romelu Lukaku      Centre-Forward        \nEverton      \nMan Utd
# 4      Virgil van Dijk         Centre-Back    \nSouthampton    \nLiverpool
# ..                 ...                 ...               ...            ...
# 245     Avilés Hurtado        Right Winger   \nClub Tijuana    \nMonterrey
# 246        Éver Banega    Central Midfield          \nInter   \nSevilla FC
# 247             Nolito         Left Winger       \nMan City   \nSevilla FC
# 248     Ryad Boudebouz  Attacking Midfield    \nMontpellier   \nReal Betis
# 249           Giuliano    Central Midfield     \nZenit S-Pb   \nFenerbahce
#
#     Market Value (m€)  Fee (m€)
# 0            €100.00m  €222.00m
# 1             €90.00m  €135.00m
# 2             €33.00m  €135.00m
# 3             €50.00m   €84.70m
# 4             €30.00m   €84.65m
# ..                ...       ...
# 245            €2.50m    €7.13m
# 246           €16.00m    €7.00m
# 247           €12.00m    €7.00m
# 248           €10.00m    €7.00m
# 249            €9.00m    €7.00m
#
# [250 rows x 6 columns]

# %%
# Clean up the data
df["Left Club"] = df["Left Club"].str.replace("\n", "").str.strip()
df["Current Club"] = df["Current Club"].str.replace("\n", "").str.strip()
df['Fee (m€)'] = df['Fee (m€)'].str.replace('€', '').str.replace('m', '')
df['Market Value (m€)'] = df['Market Value (m€)'].str.replace('€', '').str.replace('m', '')

df['Market Value (m€)'] = pd.to_numeric(df['Market Value (m€)'], errors='coerce')
df['Fee (m€)'] = pd.to_numeric(df['Fee (m€)'], errors='coerce')

df
# Out:
#            Player Name     Player Position      Left Club Current Club  \
# 0               Neymar         Left Winger      Barcelona     Paris SG
# 1    Philippe Coutinho  Attacking Midfield      Liverpool    Barcelona
# 2      Ousmane Dembélé        Right Winger  Bor. Dortmund    Barcelona
# 3        Romelu Lukaku      Centre-Forward        Everton      Man Utd
# 4      Virgil van Dijk         Centre-Back    Southampton    Liverpool
# ..                 ...                 ...            ...          ...
# 245     Avilés Hurtado        Right Winger   Club Tijuana    Monterrey
# 246        Éver Banega    Central Midfield          Inter   Sevilla FC
# 247             Nolito         Left Winger       Man City   Sevilla FC
# 248     Ryad Boudebouz  Attacking Midfield    Montpellier   Real Betis
# 249           Giuliano    Central Midfield     Zenit S-Pb   Fenerbahce
#
#      Market Value (m€)  Fee (m€)
# 0                100.0    222.00
# 1                 90.0    135.00
# 2                 33.0    135.00
# 3                 50.0     84.70
# 4                 30.0     84.65
# ..                 ...       ...
# 245                2.5      7.13
# 246               16.0      7.00
# 247               12.0      7.00
# 248               10.0      7.00
# 249                9.0      7.00
#
# [250 rows x 6 columns]

# %%
# Get out rows where the the player either left or joined Everton
everton_df = df[(df['Left Club'] == 'Everton') | (df['Current Club'] == 'Everton')]
everton_df
# Out:
#           Player Name     Player Position     Left Club Current Club  \
# 3       Romelu Lukaku      Centre-Forward       Everton      Man Utd
# 13   Gylfi Sigurdsson  Attacking Midfield       Swansea      Everton
# 39      Michael Keane         Centre-Back       Burnley      Everton
# 40    Jordan Pickford          Goalkeeper    Sunderland      Everton
# 44      Davy Klaassen    Central Midfield          Ajax      Everton
# 58       Theo Walcott        Right Winger       Arsenal      Everton
# 59         Cenk Tosun      Centre-Forward      Besiktas      Everton
# 97       Ross Barkley    Central Midfield       Everton      Chelsea
# 149   Gerard Deulofeu      Centre-Forward       Everton    Barcelona
# 172     Nikola Vlašić  Attacking Midfield  Hajduk Split      Everton
# 193     Tom Cleverley    Central Midfield       Everton      Watford
# 217    Henry Onyekuru         Left Winger     KAS Eupen      Everton
#
#      Market Value (m€)  Fee (m€)
# 3                 50.0      84.7
# 13                25.0      49.4
# 39                18.0      28.5
# 40                15.0      28.5
# 44                18.0      27.0
# 58                20.0      22.5
# 59                10.5      22.5
# 97                25.0      16.8
# 149               12.0      12.0
# 172                4.0      10.8
# 193                8.0       9.3
# 217                7.0       8.0

# %%
# From this we can see all the transfers that Everton made this season and how much they spent on each player
# We can also see the market value of each player at the time of the transfer

# Lets calculate the total fee spent by Everton and how much they got for selling players
total_spent = everton_df[everton_df['Current Club'] == 'Everton']['Fee (m€)'].sum()
total_received = everton_df[everton_df['Left Club'] == 'Everton']['Fee (m€)'].sum()
net_profit = total_received - total_spent

print("Total Spent: " + str(total_spent) + " million €")
print("Total Received: " + str(total_received) + " million €")
print("Net profit: " + str(net_profit) + " million €")
# Out:
# Total Spent: 197.2 million €
# Total Received: 122.8 million €
# Net profit: -74.39999999999999 million €

# %%
# Lets the what the squad they had at the start of the season was worth
# Need to webscrape another page to get the squad at the start of the season

# Get out Player Name, Position, Market Value
player_names = []
player_positions = []
player_values = []

headers = {'User-Agent': 
           'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

page = "https://www.transfermarkt.com/everton-fc/kader/verein/29/saison_id/2017"
pageTree = requests.get(page, headers=headers)
pageSoup = BeautifulSoup(pageTree.content, 'html.parser')

player_rows = pageSoup.find_all("tr", {"class": ["odd", "even"]})

for player_row in player_rows:
    player_name = player_row.select("a")[0].text
    player_position = player_row.select("td")[4].text
    player_value = player_row.select("td")[8].text

    player_names.append(player_name)
    player_positions.append(player_position)
    player_values.append(player_value)

everton_squad = pd.DataFrame({
    "Player Name": player_names,
    "Player Position": player_positions,
    "Left Club": None,
    "Current Club": None,
    "Market Value (m€)": player_values,
    "Fee (m€)": None
})

everton_squad['Player Name'] = everton_squad['Player Name'].str.replace("\n", "").str.strip()
everton_squad['Player Position'] = everton_squad['Player Position'].str.replace("\n", "").str.strip()
everton_squad['Market Value (m€)'] = everton_squad['Market Value (m€)'].str.replace('€', '').str.replace('m', '').str.replace('k', '')
everton_squad['Market Value (m€)'] = pd.to_numeric(everton_squad['Market Value (m€)'], errors='coerce')

everton_squad
# Out:
#               Player Name     Player Position Left Club Current Club  \
# 0         Jordan Pickford          Goalkeeper      None         None
# 1             Joel Robles          Goalkeeper      None         None
# 2    Maarten Stekelenburg          Goalkeeper      None         None
# 3          Mateusz Hewelt          Goalkeeper      None         None
# 4           Michael Keane         Centre-Back      None         None
# 5        Eliaquim Mangala         Centre-Back      None         None
# 6       Ramiro Funes Mori         Centre-Back      None         None
# 7           Mason Holgate         Centre-Back      None         None
# 8         Ashley Williams         Centre-Back      None         None
# 9            Cuco Martina         Centre-Back      None         None
# 10          Phil Jagielka         Centre-Back      None         None
# 11         Tyias Browning         Centre-Back      None         None
# 12     Matthew Pennington         Centre-Back      None         None
# 13          Morgan Feeney         Centre-Back      None         None
# 14        Michael Collins         Centre-Back      None         None
# 15        Leighton Baines           Left-Back      None         None
# 16       Brendan Galloway           Left-Back      None         None
# 17           Luke Garbutt           Left-Back      None         None
# 18         Seamus Coleman          Right-Back      None         None
# 19           Jonjoe Kenny          Right-Back      None         None
# 20    Morgan Schneiderlin  Defensive Midfield      None         None
# 21          Muhamed Besic  Defensive Midfield      None         None
# 22           Gareth Barry  Defensive Midfield      None         None
# 23             Alex Denny  Defensive Midfield      None         None
# 24          Idrissa Gueye    Central Midfield      None         None
# 25          Davy Klaassen    Central Midfield      None         None
# 26             Tom Davies    Central Midfield      None         None
# 27         James McCarthy    Central Midfield      None         None
# 28         Beni Baningime    Central Midfield      None         None
# 29         Harry Charsley    Central Midfield      None         None
# 30   Stephen Duke-McKenna      Right Midfield      None         None
# 31       Gylfi Sigurdsson  Attacking Midfield      None         None
# 32          Nikola Vlašić  Attacking Midfield      None         None
# 33         Kevin Mirallas  Attacking Midfield      None         None
# 34        Yannick Bolasie         Left Winger      None         None
# 35       Nathan Broadhead         Left Winger      None         None
# 36         Anthony Gordon         Left Winger      None         None
# 37           Theo Walcott        Right Winger      None         None
# 38           Aaron Lennon        Right Winger      None         None
# 39        Ademola Lookman      Second Striker      None         None
# 40         Shani Tarashaj      Second Striker      None         None
# 41             Cenk Tosun      Centre-Forward      None         None
# 42  Dominic Calvert-Lewin      Centre-Forward      None         None
# 43         Sandro Ramírez      Centre-Forward      None         None
# 44           Wayne Rooney      Centre-Forward      None         None
# 45           Oumar Niasse      Centre-Forward      None         None
# 46          Shayne Lavery      Centre-Forward      None         None
# 47          Fraser Hornby      Centre-Forward      None         None
#
#     Market Value (m€) Fee (m€)
# 0                30.0     None
# 1                 3.5     None
# 2                 1.0     None
# 3                 NaN     None
# 4                20.0     None
# 5                15.0     None
# 6                10.0     None
# 7                 7.0     None
# 8                 5.0     None
# 9                 2.5     None
# 10                1.5     None
# 11                1.0     None
# 12              500.0     None
# 13                NaN     None
# 14                NaN     None
# 15                8.0     None
# 16                3.0     None
# 17                1.0     None
# 18               12.0     None
# 19                5.0     None
# 20               20.0     None
# 21                5.0     None
# 22                1.0     None
# 23                NaN     None
# 24               20.0     None
# 25               15.0     None
# 26               15.0     None
# 27                8.0     None
# 28                3.0     None
# 29              250.0     None
# 30                NaN     None
# 31               30.0     None
# 32                8.0     None
# 33                7.0     None
# 34               18.0     None
# 35                NaN     None
# 36                NaN     None
# 37               20.0     None
# 38                5.0     None
# 39               12.0     None
# 40                2.0     None
# 41               23.0     None
# 42               15.0     None
# 43               10.0     None
# 44               10.0     None
# 45                8.0     None
# 46                NaN     None
# 47                NaN     None

# %%
# Put the two dataframes together (append doesnt work)
everton_df = pd.concat([everton_df, everton_squad])
# Out:
# /var/folders/lb/pwyb2dqx58gb1jd7f7zd3_rm0000gn/T/ipykernel_10430/276393758.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   everton_df = pd.concat([everton_df, everton_squad])

# %%
# sort by player name
everton_df = everton_df.sort_values(by=['Player Name'])
everton_df = everton_df.reset_index(drop=True)

# remove duplicate players and keep the last one (the one with the joined club)
everton_df = everton_df.drop_duplicates(subset=['Player Name'], keep='last')
everton_df = everton_df.reset_index(drop=True)

# Set everyone current club to Everton
everton_df['Current Club'] = 'Everton'

# Sort after market value
everton_df = everton_df.sort_values(by=['Market Value (m€)'], ascending=False)
everton_df = everton_df.reset_index(drop=True)

# The first two players market value is incorecct, 500.0 should be 0.5 and 250 should be 0.25
everton_df['Market Value (m€)'][0] = 0.5
everton_df['Market Value (m€)'][1] = 0.25

# Sort after market value (again)
everton_df = everton_df.sort_values(by=['Market Value (m€)'], ascending=False)
everton_df = everton_df.reset_index(drop=True)

everton_df
# Out:
# /var/folders/lb/pwyb2dqx58gb1jd7f7zd3_rm0000gn/T/ipykernel_10430/1889067255.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   everton_df['Market Value (m€)'][0] = 0.5
# /var/folders/lb/pwyb2dqx58gb1jd7f7zd3_rm0000gn/T/ipykernel_10430/1889067255.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   everton_df['Market Value (m€)'][1] = 0.25
#               Player Name     Player Position     Left Club Current Club  \
# 0           Romelu Lukaku      Centre-Forward       Everton      Everton
# 1            Ross Barkley    Central Midfield       Everton      Everton
# 2        Gylfi Sigurdsson  Attacking Midfield       Swansea      Everton
# 3     Morgan Schneiderlin  Defensive Midfield          None      Everton
# 4           Michael Keane         Centre-Back          None      Everton
# 5           Idrissa Gueye    Central Midfield          None      Everton
# 6            Theo Walcott        Right Winger       Arsenal      Everton
# 7         Yannick Bolasie         Left Winger          None      Everton
# 8           Davy Klaassen    Central Midfield          Ajax      Everton
# 9   Dominic Calvert-Lewin      Centre-Forward          None      Everton
# 10       Eliaquim Mangala         Centre-Back          None      Everton
# 11             Tom Davies    Central Midfield          None      Everton
# 12        Jordan Pickford          Goalkeeper    Sunderland      Everton
# 13         Seamus Coleman          Right-Back          None      Everton
# 14        Gerard Deulofeu      Centre-Forward       Everton      Everton
# 15        Ademola Lookman      Second Striker          None      Everton
# 16             Cenk Tosun      Centre-Forward      Besiktas      Everton
# 17           Wayne Rooney      Centre-Forward          None      Everton
# 18      Ramiro Funes Mori         Centre-Back          None      Everton
# 19         Sandro Ramírez      Centre-Forward          None      Everton
# 20          Tom Cleverley    Central Midfield       Everton      Everton
# 21         James McCarthy    Central Midfield          None      Everton
# 22           Oumar Niasse      Centre-Forward          None      Everton
# 23        Leighton Baines           Left-Back          None      Everton
# 24         Kevin Mirallas  Attacking Midfield          None      Everton
# 25          Mason Holgate         Centre-Back          None      Everton
# 26         Henry Onyekuru         Left Winger     KAS Eupen      Everton
# 27           Aaron Lennon        Right Winger          None      Everton
# 28          Muhamed Besic  Defensive Midfield          None      Everton
# 29           Jonjoe Kenny          Right-Back          None      Everton
# 30        Ashley Williams         Centre-Back          None      Everton
# 31          Nikola Vlašić  Attacking Midfield  Hajduk Split      Everton
# 32            Joel Robles          Goalkeeper          None      Everton
# 33       Brendan Galloway           Left-Back          None      Everton
# 34         Beni Baningime    Central Midfield          None      Everton
# 35           Cuco Martina         Centre-Back          None      Everton
# 36         Shani Tarashaj      Second Striker          None      Everton
# 37          Phil Jagielka         Centre-Back          None      Everton
# 38         Tyias Browning         Centre-Back          None      Everton
# 39           Gareth Barry  Defensive Midfield          None      Everton
# 40           Luke Garbutt           Left-Back          None      Everton
# 41   Maarten Stekelenburg          Goalkeeper          None      Everton
# 42     Matthew Pennington         Centre-Back          None      Everton
# 43         Harry Charsley    Central Midfield          None      Everton
# 44             Alex Denny  Defensive Midfield          None      Everton
# 45         Anthony Gordon         Left Winger          None      Everton
# 46          Fraser Hornby      Centre-Forward          None      Everton
# 47         Mateusz Hewelt          Goalkeeper          None      Everton
# 48        Michael Collins         Centre-Back          None      Everton
# 49          Morgan Feeney         Centre-Back          None      Everton
# 50       Nathan Broadhead         Left Winger          None      Everton
# 51          Shayne Lavery      Centre-Forward          None      Everton
# 52   Stephen Duke-McKenna      Right Midfield          None      Everton
#
#     Market Value (m€)  Fee (m€)
# 0               50.00      84.7
# 1               25.00      16.8
# 2               25.00      49.4
# 3               20.00       NaN
# 4               20.00       NaN
# 5               20.00       NaN
# 6               20.00      22.5
# 7               18.00       NaN
# 8               18.00      27.0
# 9               15.00       NaN
# 10              15.00       NaN
# 11              15.00       NaN
# 12              15.00      28.5
# 13              12.00       NaN
# 14              12.00      12.0
# 15              12.00       NaN
# 16              10.50      22.5
# 17              10.00       NaN
# 18              10.00       NaN
# 19              10.00       NaN
# 20               8.00       9.3
# 21               8.00       NaN
# 22               8.00       NaN
# 23               8.00       NaN
# 24               7.00       NaN
# 25               7.00       NaN
# 26               7.00       8.0
# 27               5.00       NaN
# 28               5.00       NaN
# 29               5.00       NaN
# 30               5.00       NaN
# 31               4.00      10.8
# 32               3.50       NaN
# 33               3.00       NaN
# 34               3.00       NaN
# 35               2.50       NaN
# 36               2.00       NaN
# 37               1.50       NaN
# 38               1.00       NaN
# 39               1.00       NaN
# 40               1.00       NaN
# 41               1.00       NaN
# 42               0.50       NaN
# 43               0.25       NaN
# 44                NaN       NaN
# 45                NaN       NaN
# 46                NaN       NaN
# 47                NaN       NaN
# 48                NaN       NaN
# 49                NaN       NaN
# 50                NaN       NaN
# 51                NaN       NaN
# 52                NaN       NaN

# %%
# Lets calculate the total value of the squad at the start of the season
total_value = everton_df['Market Value (m€)'].sum()
print("Total Value: " + str(total_value) + " million €")
# Out:
# Total Value: 449.75 million €
